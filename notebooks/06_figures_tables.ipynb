# %% [markdown]
# ### Imagens geradas
#
# Ex:
# - Figura 1 — Área de estudo
# - Figura 2 — Representações territoriais
# - Figura 3 — Distribuição da renda por escala
# - Figura 4 — Métrica × escala
# - Figura 5 — Moran's I × escala
# - Figura 6 — Persistência espacial
#
# - Tabela 1 — Estatísticas descritivas
# - Tabela 2 — Métricas por escala
# - Tabela 3 — Autocorrelação espacial
# - Tabela 4 — Estabilidade dos resultados
