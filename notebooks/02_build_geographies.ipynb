# %% [markdown]
# ### Representação territorial
#
# Construção das geometrias que serão comparadas.
#
# PORTO ALEGRE
# │
# ├── setores
# │
# ├── bairros
# │
# └── grades
#     ├── 250 m
#     ├── 500 m
#     ├── 1 km
#     └── 2 km
