# %% [markdown]
# ### Avaliação da construção da variavel renda
# "controle de qualidade da variável central"
#
# ri = Ri/Pi
#
# onde:
#
# Ri = rendimento domiciliar total;
# Pi = população correspondente;
# ri = renda per capita.
