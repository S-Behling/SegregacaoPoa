# %% [markdown]
# ### Quais resultados permanecem quando mudamos a representação espacial?
#
# - correlação entre resultados;
# - mudança de rankings;
# - concordância;
# - sobreposição espacial;
# - persistência de clusters;
# - estabilidade de áreas críticas.
